# %% [markdown]
# <a href="https://colab.research.google.com/github/duongnhathuy/A_I/blob/main/Advertising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'Advertising.csv'
data = pd.read_csv(url)
import matplotlib.pyplot as plt
#mpg so dam di chuyen trong 1 galong
#disp the tich buong dot
#hp la ma luc
#wt la khoi luong
data.hist() #So lan lap lai cua data
plt.show()

# %%
#Su tuong quan giua cac dai luong
correlation = data.corr()
print(correlation)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind= 'scatter', x = 'TV', y = 'sales', figsize = (6 , 6), color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='TV', ylabel='sales'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['TV']), y= data['sales'])
print(model.intercept_)
print(model.coef_)
# Out:
# 7.032593549127695
# [0.04753664]

# %%
#Do chinh xac
model.score(X = pd.DataFrame(data['TV']), y= data['sales'])
# Out:
# 0.611875050850071

# %%
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'yellow')
y_pred = model.predict(X = pd.DataFrame(data['TV']))
plt.plot(data['TV'], y_pred, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Mo hinh bac 2
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'], data['TV']**2]).T
model.fit(X, y= data['sales'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['sales']))
#Ve do thi mo hinh bac 2
import numpy as np
range = np.arange(1.5,300,0.1)
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['sales']))

#Mo hinh bac 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3]).T
model.fit(X, y= data['sales'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['sales']))
#Ve do thi mo hinh bac 3
import numpy as np
range = np.arange(1.5,300,0.1)
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['sales']))

#Mo hinh bac 4
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3, data['TV']**4]).T
model.fit(X, y= data['sales'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['sales']))
#Ve do thi mo hinh bac 4
import numpy as np
range = np.arange(1.5,300,0.1)
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['sales']))

#Mo hinh bac 8
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3, data['TV']**4, data['TV']**5, data['TV']**6, data['TV']**7, data['TV']**8]).T
model.fit(X, y= data['sales'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['sales']))
#Ve do thi mo hinh bac 8
import numpy as np
range = np.arange(1.5,300,0.1)
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['sales']))

#Mo hinh bac 20
model = linear_model.LinearRegression()
X = pd.DataFrame([data['TV'], data['TV']**2, data['TV']**3, data['TV']**4, data['TV']**5
                  , data['TV']**6, data['TV']**7, data['TV']**8, data['TV']**9, data['TV']**10
                  ,data['TV']**11, data['TV']**12, data['TV']**13, data['TV']**14, data['TV']**15]).T
model.fit(X, y= data['sales'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['sales']))
#Ve do thi mo hinh bac 20
import numpy as np
range = np.arange(1.5,300,0.1)
data.plot(kind= 'scatter', x = 'TV', y= 'sales', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6, range**7, range**8, range**9, range**10
                          ,range**11, range**12, range**13, range**14, range**15]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['sales']))
# Out:
# Intercept cua mo hinh: 6.1141201283331075
# Coefficient cua mo hinh [ 6.72659270e-02 -6.84693373e-05]
# Do chinh xac cua mo hinh 0.6190371168872755
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Do chinh xac cua model 0.6190371168872755
# Intercept cua mo hinh: 5.420106548191448
# Coefficient cua mo hinh [ 9.64341770e-02 -3.15222433e-04  5.57199796e-07]
# Do chinh xac cua mo hinh 0.6220016830036417
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Do chinh xac cua model 0.6220016830036417
# Intercept cua mo hinh: 4.924467214340826
# Coefficient cua mo hinh [ 1.31058582e-01 -8.44179578e-04  3.32579391e-06 -4.64690764e-09]
# Do chinh xac cua mo hinh 0.6230005614054416
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Do chinh xac cua model 0.6230005614054416
# Intercept cua mo hinh: 6.838387245169621
# Coefficient cua mo hinh [ 4.40764432e-08  6.58035568e-07  6.39255380e-05 -1.37360206e-06
#   1.23353109e-08 -5.57350480e-11  1.24960052e-13 -1.10626950e-16]
# Do chinh xac cua mo hinh 0.6162556725629602
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Do chinh xac cua model 0.6162556725629602
# Intercept cua mo hinh: 10.189613899267862
# Coefficient cua mo hinh [ 1.02578337e-43 -2.28789136e-26  5.09403482e-31 -3.63659396e-33
#   9.03923243e-35  1.19687564e-32  1.58066652e-30  1.89080731e-28
#   1.95198252e-26  1.57811213e-24  7.70603410e-23 -1.15186141e-24
#   6.46365016e-27 -1.61256231e-29  1.50826047e-32]
# Do chinh xac cua mo hinh 0.5255073174928855
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Do chinh xac cua model 0.5255073174928855
