# %% [markdown]
# <a href="https://colab.research.google.com/github/duongnhathuy/A_I/blob/main/Fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import fashion_mnist 
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()

# %%
import matplotlib.pyplot as plt
hinh = x_train[100]
plt.imshow(hinh, cmap = plt.cm.binary)
plt.show
print('So nay la:{}' .format(y_train[100]))
# Out:
# So nay la:8

# %%
for i in range(30):
  plt.subplot(5,6,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i], cmap='gray', interpolation='none')
  plt.title('So:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras import models
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical 

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(28*28*1,), name='Lop1'))
model.add(Dense(10, activation='softmax', name='Lopra'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Lop1 (Dense)                (None, 512)               401920
#
#  Lopra (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((60000, 28*28*1))
x_train = x_train.astype('float32')/255
x_test = x_test.reshape((10000, 28*28*1))
x_test = x_test.astype('float32')/255

from keras.utils import to_categorical
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
model.compile(optimizer ='rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 50, batch_size = 180)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Accurency', test_acc)
print('Loss', test_loss)
# Out:
# Epoch 1/50
# 334/334 [==============================] - 3s 3ms/step - loss: 0.5941 - accuracy: 0.7893
# Epoch 2/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.4021 - accuracy: 0.8538
# Epoch 3/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.3534 - accuracy: 0.8702
# Epoch 4/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.3251 - accuracy: 0.8799
# Epoch 5/50
# 334/334 [==============================] - 2s 6ms/step - loss: 0.3019 - accuracy: 0.8886
# Epoch 6/50
# 334/334 [==============================] - 2s 6ms/step - loss: 0.2868 - accuracy: 0.8932
# Epoch 7/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.2699 - accuracy: 0.9008
# Epoch 8/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.2618 - accuracy: 0.9031
# Epoch 9/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.2499 - accuracy: 0.9060
# Epoch 10/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.2378 - accuracy: 0.9116
# Epoch 11/50
# 334/334 [==============================] - 2s 5ms/step - loss: 0.2336 - accuracy: 0.9133
# Epoch 12/50
# 334/334 [==============================] - 2s 7ms/step - loss: 0.2244 - accuracy: 0.9168
# Epoch 13/50
# 334/334 [==============================] - 2s 6ms/step - loss: 0.2148 - accuracy: 0.9196
# Epoch 14/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.2099 - accuracy: 0.9218
# Epoch 15/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.2032 - accuracy: 0.9234
# Epoch 16/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1965 - accuracy: 0.9261
# Epoch 17/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1900 - accuracy: 0.9293
# Epoch 18/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1834 - accuracy: 0.9322
# Epoch 19/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1786 - accuracy: 0.9333
# Epoch 20/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1739 - accuracy: 0.9352
# Epoch 21/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1695 - accuracy: 0.9370
# Epoch 22/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1640 - accuracy: 0.9398
# Epoch 23/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1594 - accuracy: 0.9405
# Epoch 24/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1558 - accuracy: 0.9409
# Epoch 25/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1516 - accuracy: 0.9438
# Epoch 26/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1469 - accuracy: 0.9443
# Epoch 27/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1426 - accuracy: 0.9470
# Epoch 28/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1412 - accuracy: 0.9474
# Epoch 29/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1362 - accuracy: 0.9495
# Epoch 30/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1333 - accuracy: 0.9504
# Epoch 31/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1300 - accuracy: 0.9521
# Epoch 32/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1279 - accuracy: 0.9526
# Epoch 33/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1228 - accuracy: 0.9551
# Epoch 34/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1206 - accuracy: 0.9543
# Epoch 35/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1185 - accuracy: 0.9567
# Epoch 36/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1136 - accuracy: 0.9582
# Epoch 37/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1106 - accuracy: 0.9590
# Epoch 38/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1104 - accuracy: 0.9591
# Epoch 39/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1087 - accuracy: 0.9601
# Epoch 40/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1041 - accuracy: 0.9622
# Epoch 41/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1030 - accuracy: 0.9616
# Epoch 42/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.1015 - accuracy: 0.9624
# Epoch 43/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0975 - accuracy: 0.9641
# Epoch 44/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0965 - accuracy: 0.9640
# Epoch 45/50
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0959 - accuracy: 0.9645
# Epoch 46/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0926 - accuracy: 0.9662
# Epoch 47/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0921 - accuracy: 0.9665
# Epoch 48/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0872 - accuracy: 0.9676
# Epoch 49/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0887 - accuracy: 0.9671
# Epoch 50/50
# 334/334 [==============================] - 1s 3ms/step - loss: 0.0861 - accuracy: 0.9682
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5795 - accuracy: 0.8762
# Accurency 0.8762000203132629
# Loss 0.5795366764068604

# %%
model.save('cifar10.h5')

# %%
classes_keys = {0: 'T-Shirt/Top', 1: 'Trouser', 2: 'Pullover', 3: 'Dress', 
                4: 'Coat', 5: 'Sandals', 6: 'Shirt', 7: 'Sneaker', 8: 'Bag', 9: 'Ankle boots'}

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from keras.utils import load_img
from keras.utils import img_to_array
from pylab import *
import numpy as np

from PIL import Image

url = 'nike.jpg'
img = load_img(url)
plt.imshow(img)

# %%
from keras.utils import load_img, img_to_array
import numpy as np
img = load_img(url, target_size=(28,28))

plt.imshow(img)

# From image to array to predict
img = img_to_array(img)
img = img[:,:,0]
plt.imshow(img)
img = img.astype('float32')
img = img/255
pred_value = np.argmax(model.predict(img.reshape( 1,28*28), verbose=False),)

# Check the class
for keys in classes_keys.keys():
  if pred_value == keys:
    plt.title(classes_keys[keys])
    break
  else:
    continue
